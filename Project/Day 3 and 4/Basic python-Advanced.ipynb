# %% [markdown]
# Jalaludin Shofa

# %% [markdown]
# Business Intelligence Batch 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy.linalg import inv

# %%
df = pd.read_csv("D:/Dibimbing/Day 3 and 4/linear-regression.csv")
df_new = pd.concat([pd.DataFrame(df.columns,index=df.columns).T,df])
df_new.columns = ['X','y']
df_new['X'] = df_new['X'].astype(float)
df_new['y'] = df_new['y'].astype(float)

# %% [markdown]
# # 1

# %%
plt.scatter(df_new['X'].values,df_new['y'].values,label='random data')
plt.legend()
plt.show()

# %% [markdown]
# # 2

# %%
matrix_new = [matrix[:,0],matrix[:,1],[1]*len(df_new)]
zero = [0]*len(df_new)

# %%
matrix = np.array(df_new.values)

# %%
X,y = matrix[:,0], matrix[:,1]
X_mat=np.vstack((np.ones(len(X)), X)).T

# %%
x = inv(X_mat.T.dot(X_mat)).dot(X_mat.T).dot(y)
y_pred = X_mat.dot(x)

# %%
plt.scatter(X,y)
plt.plot(X,y_pred,color='red')
plt.text(0.1,1.5,'B1 = {}'.format(x[1]))
plt.text(0.1,2,'B0 = {}'.format(x[0]))
plt.show()

# %% [markdown]
# # 3

# %%
A = np.array([X.reshape(-1),np.ones(len(X))])

# %%
w = np.linalg.lstsq(A.T,y)[0]
# Out:
# C:\Users\jalal\AppData\Local\Temp\ipykernel_8544\2008872504.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   w = np.linalg.lstsq(A.T,y)[0]

# %%
line = w[0]*X.reshape(-1)+w[1]
plt.plot(X,line,'r-',X,y,'o')
plt.text(0.1,1.5,'B1 = {}'.format(x[1]))
plt.text(0.1,2,'B0 = {}'.format(x[0]))
plt.show()
